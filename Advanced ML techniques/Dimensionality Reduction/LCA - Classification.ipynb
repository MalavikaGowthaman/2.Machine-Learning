# %%
# import lib
import pandas as pd
import numpy as np
import time
import matplotlib.pyplot as plt

# %%
dataset = pd.read_csv('Placement.csv')
dataset
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0        1      M  67.00   Others  91.00   Others  Commerce     58.00
# 1        2      M  79.33  Central  78.33   Others   Science     77.48
# 2        3      M  65.00  Central  68.00  Central      Arts     64.00
# 3        4      M  56.00  Central  52.00  Central   Science     52.00
# 4        5      M  85.80  Central  73.60  Central  Commerce     73.30
# ..     ...    ...    ...      ...    ...      ...       ...       ...
# 210    211      M  80.60   Others  82.00   Others  Commerce     77.60
# 211    212      M  58.00   Others  60.00   Others   Science     72.00
# 212    213      M  67.00   Others  67.00   Others  Commerce     73.00
# 213    214      F  74.00   Others  66.00   Others  Commerce     58.00
# 214    215      M  62.00  Central  58.00   Others   Science     53.00
#
#       degree_t workex  etest_p specialisation  mba_p      status    salary
# ...

# %%
df = dataset
df.isna().sum()
# Out:
# sl_no              0
# gender             0
# ssc_p              0
# ssc_b              0
# hsc_p              0
# hsc_b              0
# hsc_s              0
# degree_p           0
# degree_t           0
# workex             0
# etest_p            0
# specialisation     0
# mba_p              0
# status             0
# salary            67
# dtype: int64

# %%
df['salary'].fillna(0,inplace =True)
df
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0        1      M  67.00   Others  91.00   Others  Commerce     58.00
# 1        2      M  79.33  Central  78.33   Others   Science     77.48
# 2        3      M  65.00  Central  68.00  Central      Arts     64.00
# 3        4      M  56.00  Central  52.00  Central   Science     52.00
# 4        5      M  85.80  Central  73.60  Central  Commerce     73.30
# ..     ...    ...    ...      ...    ...      ...       ...       ...
# 210    211      M  80.60   Others  82.00   Others  Commerce     77.60
# 211    212      M  58.00   Others  60.00   Others   Science     72.00
# 212    213      M  67.00   Others  67.00   Others  Commerce     73.00
# 213    214      F  74.00   Others  66.00   Others  Commerce     58.00
# 214    215      M  62.00  Central  58.00   Others   Science     53.00
#
#       degree_t workex  etest_p specialisation  mba_p      status    salary
# ...

# %%
df= pd.get_dummies(df,drop_first =True)
df =df.astype(int)
df
# Out:
#      sl_no  ssc_p  hsc_p  degree_p  etest_p  mba_p  salary  gender_M  \
# 0        1     67     91        58       55     58  270000         1
# 1        2     79     78        77       86     66  200000         1
# 2        3     65     68        64       75     57  250000         1
# 3        4     56     52        52       66     59       0         1
# 4        5     85     73        73       96     55  425000         1
# ..     ...    ...    ...       ...      ...    ...     ...       ...
# 210    211     80     82        77       91     74  400000         1
# 211    212     58     60        72       74     53  275000         1
# 212    213     67     67        73       59     69  295000         1
# 213    214     74     66        58       70     60  204000         0
# 214    215     62     58        53       89     60       0         1
#
#      ssc_b_Others  hsc_b_Others  hsc_s_Commerce  hsc_s_Science  \
# 0               1             1               1              0
# ...

# %%
df.to_csv('Preplacement.csv',index =False)

# %%
indep_X =  df.drop(['salary','sl_no'],axis =1)
dep_Y = df['salary']

# %%
# spliting the input and output, to perform std scaler
def split_scaler(indep_X,dep_Y):
    from sklearn.model_selection import train_test_split
    from sklearn.preprocessing import StandardScaler
    X_train,X_test,Y_train,Y_test = train_test_split(indep_X,dep_Y,test_size = 0.25,random_state = 0)
    sc= StandardScaler()
    X_train = sc.fit_transform(X_train)
    X_test = sc.transform(X_test)
    return X_train,X_test,Y_train,Y_test

# %%
# to apply pca

def lda(X_train,Y_train,n):
    from sklearn.discriminant_analysis import LinearDiscriminantAnalysis as LDA
    lda = LDA(n_components = n)
    X_train = lda.fit_transform(X_train,Y_train)
    return lda,X_train

# %%
# confusion matrix
def cm_pred(classifier,X_test):
    test_pred = classifier.predict(X_test)
    from sklearn.metrics import confusion_matrix
    cm = confusion_matrix(Y_test,test_pred)
    from sklearn.metrics import accuracy_score
    accuracy = accuracy_score(Y_test,test_pred)
    return classifier,cm, accuracy

# %%
# logistics regression

def log(X_train,X_test,Y_train):
    from sklearn.linear_model import LogisticRegression
    classifier = LogisticRegression(random_state = 0)
    classifier.fit(X_train, Y_train)
    classifier,cm,accuracy = cm_pred(classifier,X_test)
    return classifier,cm,accuracy

# %%
# svm classfier

def svm_linear(X_train,X_test,Y_train):
    from sklearn.svm import SVC
    classifier = SVC(kernel = 'linear',random_state =0)
    classifier.fit(X_train, Y_train)
    classifier,cm,accuracy = cm_pred(classifier,X_test)
    return classifier,cm,accuracy

# %%
# svm classfier

def svm_nonlinear(X_train,X_test,Y_train):
    from sklearn.svm import SVC
    classifier = SVC(kernel = 'rbf',random_state =0)
    classifier.fit(X_train, Y_train)
    classifier,cm,accuracy = cm_pred(classifier,X_test)
    return classifier,cm,accuracy

# %%
# Navie Bayes classfier

def navie(X_train,X_test,Y_train):
    from sklearn.naive_bayes import GaussianNB
    classifier = GaussianNB()
    classifier.fit(X_train, Y_train)
    classifier,cm,accuracy = cm_pred(classifier,X_test)
    return classifier,cm,accuracy

# %%
# knn classfier

def knn(X_train,X_test,Y_train):
    from sklearn.neighbors import KNeighborsClassifier
    classifier = KNeighborsClassifier(n_neighbors = 5, metric = 'minkowski', p = 2)
    classifier.fit(X_train, Y_train)
    classifier,cm,accuracy = cm_pred(classifier,X_test)
    return classifier,cm,accuracy

# %%
# random forest classfier

def random(X_train,X_test,Y_train):
    from sklearn.ensemble import RandomForestClassifier
    classifier = RandomForestClassifier(n_estimators = 10, criterion = 'entropy', random_state = 0)
    classifier.fit(X_train, Y_train)
    classifier,cm,accuracy = cm_pred(classifier,X_test)
    return classifier,cm,accuracy

# %%
# decision tree classfier

def decision(X_train,X_test,Y_train):
    from sklearn.tree import DecisionTreeClassifier
    classifier = DecisionTreeClassifier(criterion = 'entropy', random_state = 0)
    classifier.fit(X_train, Y_train)
    classifier,cm,accuracy = cm_pred(classifier,X_test)
    return classifier,cm,accuracy

# %%
# to create df

def lda_df(acclog,accsvml,accsvmnl,accnb,accknn,accrf,accdt):
    df2 = pd.DataFrame(index =['LDA = 10'],columns =['Logistic','SVMLinear','SVMNL','NavieBayes','KNN','RandomForest','DecisionTree'])
    for number,index in enumerate(df2.index):
        df2['Logistic'][index]=acclog[number]
        df2['SVMLinear'][index]=accsvml[number]
        df2['SVMNL'][index]=accsvmnl[number]
        df2['NavieBayes'][index]=accnb[number]
        df2['KNN'][index]=accknn[number]
        df2['RandomForest'][index]=accrf[number]
        df2['DecisionTree'][index]=accdt[number]
    return df2

# %%
lda= lda(indep_X,dep_Y,10)
acclog=[]
accsvml =[]
accsvmnl =[]
accnb =[]
accknn =[]
accrf =[]
accdt =[]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[69], line 1
# ----> 1 lda= lda(indep_X,dep_Y,10)
#       2 acclog=[]
#       3 accsvml =[]
#
# TypeError: 'tuple' object is not callable

# %%
X_train,X_test,Y_train,Y_test = split_scaler(indep_X,dep_Y)

classifier,cm,accuracy = log(X_train,X_test,Y_train)
acclog.append(accuracy)

classifier,cm,accuracy = svm_linear(X_train,X_test,Y_train)
accsvml.append(accuracy)

classifier,cm,accuracy = svm_nonlinear(X_train,X_test,Y_train)
accsvmnl.append(accuracy)

classifier,cm,accuracy = navie(X_train,X_test,Y_train)
accnb.append(accuracy)

classifier,cm,accuracy = knn(X_train,X_test,Y_train)
accknn.append(accuracy)

classifier,cm,accuracy = random(X_train,X_test,Y_train)
accrf.append(accuracy)

classifier,cm,accuracy = decision(X_train,X_test,Y_train)
accdt.append(accuracy)

result = lda_df(acclog,accsvml,accsvmnl,accnb,accknn,accrf,accdt)

# %%
result
# Out:
#           Logistic SVMLinear    SVMNL NavieBayes       KNN RandomForest  \
# LDA = 10  0.351852  0.333333  0.37037   0.333333  0.296296     0.314815
#
#          DecisionTree
# LDA = 10     0.333333

# %%
result
# Out:
#           Logistic SVMLinear    SVMNL NavieBayes       KNN RandomForest  \
# LDA = 15  0.351852  0.333333  0.37037   0.333333  0.296296     0.314815
#
#          DecisionTree
# LDA = 15     0.333333
