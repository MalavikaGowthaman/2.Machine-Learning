# %%
# importing library
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#loading dataset
dataset = pd.read_csv("insurance_pre.csv")
dataset
# Out:
#       age     sex     bmi  children smoker      charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# ...   ...     ...     ...       ...    ...          ...
# 1333   50    male  30.970         3     no  10600.54830
# 1334   18  female  31.920         0     no   2205.98080
# 1335   18  female  36.850         0     no   1629.83350
# 1336   21  female  25.800         0     no   2007.94500
# 1337   61  female  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %%
#transform categorical value to numerical value
dataset = pd.get_dummies(dataset, drop_first =True)
dataset = dataset.astype(int)
dataset
# Out:
#       age  bmi  children  charges  sex_male  smoker_yes
# 0      19   27         0    16884         0           1
# 1      18   33         1     1725         1           0
# 2      28   33         3     4449         1           0
# 3      33   22         0    21984         1           0
# 4      32   28         0     3866         1           0
# ...   ...  ...       ...      ...       ...         ...
# 1333   50   30         3    10600         1           0
# 1334   18   31         0     2205         0           0
# 1335   18   36         0     1629         0           0
# 1336   21   25         0     2007         0           0
# 1337   61   29         0    29141         0           1
#
# [1338 rows x 6 columns]

# %%
dataset.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='object')

# %%
independent = dataset[['age', 'bmi', 'children','sex_male', 'smoker_yes']]
dependent = dataset[['charges']]

# %%
from sklearn.tree import DecisionTreeRegressor #importing decision tree
from sklearn.model_selection import GridSearchCV # importing gridsearch to make the crossvalidation 
parameters = {'criterion':['squared_error', 'friedman_mse', 'absolute_error', 'poisson'], # paramters are svr from website
              'splitter':['best', 'random'],
              'max_features':['sqrt', 'log2']}

grid = GridSearchCV(DecisionTreeRegressor(),parameters, refit = True, verbose =3, n_jobs=-1) #refit true is for finding the best model,
                                                                           #false will give last model
grid.fit(independent,dependent) # can able to call directly without training and testing
# Out:
# Fitting 5 folds for each of 16 candidates, totalling 80 fits
# GridSearchCV(estimator=DecisionTreeRegressor(), n_jobs=-1,
#              param_grid={'criterion': ['squared_error', 'friedman_mse',
#                                        'absolute_error', 'poisson'],
#                          'max_features': ['sqrt', 'log2'],
#                          'splitter': ['best', 'random']},
#              verbose=3)

# %%
print(grid.best_params_)
# Out:
# {'criterion': 'poisson', 'max_features': 'sqrt', 'splitter': 'best'}

# %%
regressor =grid.cv_results_ 
regressor
print('The R score value for best parameter: ',format(grid.best_params_))
# Out:
# The R score value for best parameter:  {'criterion': 'poisson', 'max_features': 'sqrt', 'splitter': 'best'}

# %%
table = pd.DataFrame.from_dict(regressor)
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.039310      0.017557         0.008803        0.006227
# 1        0.036208      0.015262         0.009852        0.016016
# 2        0.031549      0.015519         0.011749        0.007933
# 3        0.037106      0.027281         0.004634        0.003806
# 4        0.015256      0.002986         0.012712        0.006391
# 5        0.016226      0.010861         0.009373        0.007653
# 6        0.027559      0.018155         0.008850        0.007289
# 7        0.020086      0.006110         0.010769        0.006339
# 8        0.085476      0.019249         0.007520        0.004958
# 9        0.085227      0.014682         0.004533        0.006179
# 10       0.081718      0.013147         0.007584        0.010932
# 11       0.073327      0.012139         0.012640        0.014228
# 12       0.019739      0.009325         0.005052        0.006837
# 13       0.021442      0.006091         0.007352        0.007047
# 14       0.031243      0.017112         0.004489        0.008978
# 15       0.025588      0.014383         0.009097        0.006055
#
#    param_criterion param_max_features param_splitter  \
# 0    squared_error               sqrt           best
# 1    squared_error               sqrt         random
# 2    squared_error               log2           best
# 3    squared_error               log2         random
# 4     friedman_mse               sqrt           best
# 5     friedman_mse               sqrt         random
# 6     friedman_mse               log2           best
# 7     friedman_mse               log2         random
# 8   absolute_error               sqrt           best
# 9   absolute_error               sqrt         random
# 10  absolute_error               log2           best
# 11  absolute_error               log2         random
# 12         poisson               sqrt           best
# 13         poisson               sqrt         random
# 14         poisson               log2           best
# 15         poisson               log2         random
#
#                                                params  split0_test_score  \
# 0   {'criterion': 'squared_error', 'max_features':...           0.719489
# 1   {'criterion': 'squared_error', 'max_features':...           0.712228
# 2   {'criterion': 'squared_error', 'max_features':...           0.756891
# 3   {'criterion': 'squared_error', 'max_features':...           0.699677
# 4   {'criterion': 'friedman_mse', 'max_features': ...           0.634467
# 5   {'criterion': 'friedman_mse', 'max_features': ...           0.687836
# 6   {'criterion': 'friedman_mse', 'max_features': ...           0.705989
# 7   {'criterion': 'friedman_mse', 'max_features': ...           0.601065
# 8   {'criterion': 'absolute_error', 'max_features'...           0.755077
# 9   {'criterion': 'absolute_error', 'max_features'...           0.654950
# 10  {'criterion': 'absolute_error', 'max_features'...           0.684020
# 11  {'criterion': 'absolute_error', 'max_features'...           0.577402
# 12  {'criterion': 'poisson', 'max_features': 'sqrt...           0.652649
# 13  {'criterion': 'poisson', 'max_features': 'sqrt...           0.710154
# 14  {'criterion': 'poisson', 'max_features': 'log2...           0.735548
# 15  {'criterion': 'poisson', 'max_features': 'log2...           0.714748
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.510247           0.691573           0.728304
# 1            0.619843           0.679331           0.672536
# 2            0.540111           0.690863           0.728412
# 3            0.626646           0.700264           0.599630
# 4            0.582884           0.713008           0.730915
# 5            0.481015           0.666473           0.729003
# 6            0.629266           0.680190           0.605000
# 7            0.586210           0.735202           0.660209
# 8            0.519540           0.701019           0.746252
# 9            0.579902           0.716980           0.629755
# 10           0.604494           0.653038           0.688488
# 11           0.555163           0.697211           0.616758
# 12           0.641179           0.713628           0.764598
# 13           0.598479           0.718525           0.733632
# 14           0.642254           0.317559           0.750224
# 15           0.534626           0.697307           0.652909
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0            0.722538         0.674430        0.083063                5
# 1            0.667425         0.670273        0.029661                6
# 2            0.630673         0.669390        0.077218                7
# 3            0.669520         0.659147        0.040099                9
# 4            0.725196         0.677294        0.058639                4
# 5            0.729128         0.658691        0.092070               11
# 6            0.686299         0.661349        0.037881                8
# 7            0.560826         0.628702        0.062468               15
# 8            0.718377         0.688053        0.086445                3
# 9            0.704473         0.657212        0.050083               12
# 10           0.665508         0.659110        0.030147               10
# 11           0.617843         0.612875        0.048459               16
# 12           0.744148         0.703240        0.048902                1
# 13           0.739459         0.700050        0.051848                2
# 14           0.757672         0.640651        0.166791               13
# 15           0.580657         0.636050        0.068681               14

# %%
dataset.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='object')

# %%
age = float(input("Age: "))
bmi = float(input("BMI: "))
children = int(input("No of Children: "))
sex_male= int(input("Sex Male :0 , Female: 1: "))
smoker_yes= int(input("Smoker: 0, Non-smoker:1: "))
# Out:
# Age: 23
# BMI: 45.6
# No of Children: 3
# Sex Male :0 , Female: 1: 1
# Smoker: 0, Non-smoker:1: 1

# %%
Final_prediction =grid.predict([[age,bmi,children,sex_male,smoker_yes]])
print("Final_prediction of Decision Tree: {}".format(Final_prediction))
# Out:
# Final_prediction of Decision Tree: [37465.]
# C:\Anaconda3\Lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(

# %%
# Saving the model
import pickle
filename= "DecisionTreeGrid_insurance.sav"

# %%
pickle.dump(grid,open(filename,'wb'))
load_model=pickle.load(open("DecisionTreeGrid_insurance.sav",'rb'))

# %%
result=load_model.predict([[29,23,1,0,1]])
result
# Out:
# C:\Anaconda3\Lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# array([18765.])
