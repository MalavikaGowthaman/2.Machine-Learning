# %%
# importing library
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#loading dataset
dataset = pd.read_csv("insurance_pre.csv")
dataset
# Out:
#       age     sex     bmi  children smoker      charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# ...   ...     ...     ...       ...    ...          ...
# 1333   50    male  30.970         3     no  10600.54830
# 1334   18  female  31.920         0     no   2205.98080
# 1335   18  female  36.850         0     no   1629.83350
# 1336   21  female  25.800         0     no   2007.94500
# 1337   61  female  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %%
#transform categorical value to numerical value
dataset = pd.get_dummies(dataset, drop_first =True)
dataset = dataset.astype(int)
dataset
# Out:
#       age  bmi  children  charges  sex_male  smoker_yes
# 0      19   27         0    16884         0           1
# 1      18   33         1     1725         1           0
# 2      28   33         3     4449         1           0
# 3      33   22         0    21984         1           0
# 4      32   28         0     3866         1           0
# ...   ...  ...       ...      ...       ...         ...
# 1333   50   30         3    10600         1           0
# 1334   18   31         0     2205         0           0
# 1335   18   36         0     1629         0           0
# 1336   21   25         0     2007         0           0
# 1337   61   29         0    29141         0           1
#
# [1338 rows x 6 columns]

# %%
independent = dataset[['age', 'bmi', 'children','sex_male', 'smoker_yes']]
dependent = dataset[['charges']]

# %%
from sklearn.ensemble import RandomForestRegressor #importing random forest
from sklearn.model_selection import GridSearchCV # importing gridsearch to make the crossvalidation 
parameters = {'n_estimators':[10,50,100],
              'criterion':['squared_error', 'friedman_mse', 'absolute_error', 'poisson'], # paramters are svr from website
              'max_features':['sqrt', 'log2']}

grid = GridSearchCV(RandomForestRegressor(),parameters, refit = True, verbose =3, n_jobs=-1) #refit true is for finding the best model,
                                                                           #false will give last model
grid.fit(independent,dependent) # can able to call directly without training and testing
# Out:
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# C:\Anaconda3\Lib\site-packages\sklearn\model_selection\_search.py:909: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   self.best_estimator_.fit(X, y, **fit_params)
# GridSearchCV(estimator=RandomForestRegressor(), n_jobs=-1,
#              param_grid={'criterion': ['squared_error', 'friedman_mse',
#                                        'absolute_error', 'poisson'],
#                          'max_features': ['sqrt', 'log2'],
#                          'n_estimators': [10, 50, 100]},
#              verbose=3)

# %%
print(grid.best_params_)
# Out:
# {'criterion': 'absolute_error', 'max_features': 'sqrt', 'n_estimators': 100}

# %%
regressor = grid.cv_results_ 
regressor
print('The R score value for best parameter: ',format(grid.best_params_))
# Out:
# The R score value for best parameter:  {'criterion': 'absolute_error', 'max_features': 'sqrt', 'n_estimators': 100}

# %%
table = pd.DataFrame.from_dict(regressor)
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.436760      0.124666         0.015652        0.014877
# 1        1.474700      0.432498         0.073168        0.023773
# 2        2.404246      0.173002         0.112872        0.049732
# 3        0.725216      0.299330         0.043659        0.015333
# 4        1.133626      0.073041         0.063448        0.024829
# 5        2.536420      0.106914         0.093428        0.008829
# 6        0.488231      0.290124         0.044714        0.036575
# 7        1.370729      0.154132         0.074862        0.026347
# 8        2.771818      0.075560         0.127381        0.044738
# 9        0.515803      0.269890         0.050265        0.036346
# 10       1.251542      0.084515         0.072323        0.026815
# 11       2.878055      0.079387         0.114653        0.019338
# 12       1.074069      0.074982         0.031260        0.033037
# 13       5.372346      0.258437         0.099144        0.038604
# 14      10.057479      1.154857         0.090509        0.051103
# 15       1.178710      0.137559         0.030186        0.025558
# 16       5.004131      0.757880         0.070711        0.028788
# 17       9.098712      1.925228         0.109843        0.065934
# 18       0.517474      0.064473         0.029906        0.031088
# 19       1.857177      0.218160         0.080024        0.042833
# 20       3.791994      0.171024         0.124615        0.052602
# 21       0.871534      0.637906         0.027032        0.033324
# 22       1.635352      0.054647         0.078061        0.009983
# 23       2.832766      0.107755         0.088014        0.012935
#
#    param_criterion param_max_features param_n_estimators  \
# 0    squared_error               sqrt                 10
# 1    squared_error               sqrt                 50
# 2    squared_error               sqrt                100
# 3    squared_error               log2                 10
# 4    squared_error               log2                 50
# 5    squared_error               log2                100
# 6     friedman_mse               sqrt                 10
# 7     friedman_mse               sqrt                 50
# 8     friedman_mse               sqrt                100
# 9     friedman_mse               log2                 10
# 10    friedman_mse               log2                 50
# 11    friedman_mse               log2                100
# 12  absolute_error               sqrt                 10
# 13  absolute_error               sqrt                 50
# 14  absolute_error               sqrt                100
# 15  absolute_error               log2                 10
# 16  absolute_error               log2                 50
# 17  absolute_error               log2                100
# 18         poisson               sqrt                 10
# 19         poisson               sqrt                 50
# 20         poisson               sqrt                100
# 21         poisson               log2                 10
# 22         poisson               log2                 50
# 23         poisson               log2                100
#
#                                                params  split0_test_score  \
# 0   {'criterion': 'squared_error', 'max_features':...           0.837904
# 1   {'criterion': 'squared_error', 'max_features':...           0.851351
# 2   {'criterion': 'squared_error', 'max_features':...           0.857389
# 3   {'criterion': 'squared_error', 'max_features':...           0.844199
# 4   {'criterion': 'squared_error', 'max_features':...           0.852326
# 5   {'criterion': 'squared_error', 'max_features':...           0.849289
# 6   {'criterion': 'friedman_mse', 'max_features': ...           0.846036
# 7   {'criterion': 'friedman_mse', 'max_features': ...           0.849203
# 8   {'criterion': 'friedman_mse', 'max_features': ...           0.855810
# 9   {'criterion': 'friedman_mse', 'max_features': ...           0.841470
# 10  {'criterion': 'friedman_mse', 'max_features': ...           0.846875
# 11  {'criterion': 'friedman_mse', 'max_features': ...           0.850647
# 12  {'criterion': 'absolute_error', 'max_features'...           0.834016
# 13  {'criterion': 'absolute_error', 'max_features'...           0.850864
# 14  {'criterion': 'absolute_error', 'max_features'...           0.860262
# 15  {'criterion': 'absolute_error', 'max_features'...           0.844686
# 16  {'criterion': 'absolute_error', 'max_features'...           0.855884
# 17  {'criterion': 'absolute_error', 'max_features'...           0.854436
# 18  {'criterion': 'poisson', 'max_features': 'sqrt...           0.835800
# 19  {'criterion': 'poisson', 'max_features': 'sqrt...           0.853420
# 20  {'criterion': 'poisson', 'max_features': 'sqrt...           0.855067
# 21  {'criterion': 'poisson', 'max_features': 'log2...           0.847007
# 22  {'criterion': 'poisson', 'max_features': 'log2...           0.848490
# 23  {'criterion': 'poisson', 'max_features': 'log2...           0.852668
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.759012           0.834904           0.807889
# 1            0.773233           0.846670           0.820498
# 2            0.771880           0.855876           0.822801
# 3            0.733506           0.819901           0.794657
# 4            0.771409           0.852318           0.827608
# 5            0.772430           0.853974           0.826290
# 6            0.761026           0.837553           0.807965
# 7            0.767503           0.843444           0.823354
# 8            0.765683           0.846328           0.826475
# 9            0.759211           0.793927           0.806117
# 10           0.770344           0.856286           0.818305
# 11           0.769315           0.852816           0.826854
# 12           0.755410           0.846337           0.804295
# 13           0.769321           0.838661           0.820829
# 14           0.773442           0.856081           0.829071
# 15           0.751487           0.838409           0.794637
# 16           0.767953           0.858091           0.823184
# 17           0.768977           0.847958           0.830197
# 18           0.750772           0.827235           0.802166
# 19           0.768867           0.855227           0.820633
# 20           0.775935           0.855271           0.823054
# 21           0.748430           0.823525           0.809931
# 22           0.770105           0.850119           0.816491
# 23           0.775440           0.855544           0.822453
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0            0.826182         0.813178        0.029033               20
# 1            0.836924         0.825735        0.028297               13
# 2            0.835487         0.828686        0.031212                5
# 3            0.800233         0.798499        0.036847               24
# 4            0.833715         0.827475        0.029722                8
# 5            0.836682         0.827733        0.029305                7
# 6            0.833427         0.817201        0.030822               17
# 7            0.836488         0.823998        0.029535               16
# 8            0.840109         0.826881        0.032048               10
# 9            0.825605         0.805266        0.028195               23
# 10           0.840480         0.826458        0.030719               11
# 11           0.836359         0.827198        0.030465                9
# 12           0.827713         0.813554        0.032126               18
# 13           0.843890         0.824713        0.029426               14
# 14           0.841555         0.832082        0.031329                1
# 15           0.838244         0.813493        0.035796               19
# 16           0.839509         0.828924        0.032985                4
# 17           0.838410         0.827995        0.030640                6
# 18           0.818510         0.806897        0.030187               22
# 19           0.831024         0.825834        0.031382               12
# 20           0.837829         0.829431        0.029319                2
# 21           0.831217         0.812022        0.033980               21
# 22           0.836423         0.824325        0.029654               15
# 23           0.840141         0.829249        0.029326                3

# %%
dataset.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='object')

# %%
age = float(input("Age: "))
bmi = float(input("BMI: "))
children = int(input("No of Children: "))
sex_male= int(input("Sex Male :0 , Female: 1: "))
smoker_yes= int(input("Smoker: 0, Non-smoker:1: "))
# Out:
# Age: 21
# BMI: 23
# No of Children: 1
# Sex Male :0 , Female: 1: 0
# Smoker: 0, Non-smoker:1: 1

# %%
Final_prediction =grid.predict([[age,bmi,children,sex_male,smoker_yes]])
print("Final_prediction of Random Forest: {}".format(Final_prediction))
# Out:
# Final_prediction of Random Forest: [17618.27]
# C:\Anaconda3\Lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(

# %%
# Saving the model
import pickle
filename= "RandomForestGrid_insurance.sav"

# %%
pickle.dump(grid,open(filename,'wb'))
load_model=pickle.load(open("RandomForestGrid_insurance.sav",'rb'))

# %%
result=load_model.predict([[29,23,1,0,1]])
result
# Out:
# C:\Anaconda3\Lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# array([17806.42])
