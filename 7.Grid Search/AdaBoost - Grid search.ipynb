# %%
# importing library
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#loading dataset
dataset = pd.read_csv("insurance_pre.csv")
dataset
# Out:
#       age     sex     bmi  children smoker      charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# ...   ...     ...     ...       ...    ...          ...
# 1333   50    male  30.970         3     no  10600.54830
# 1334   18  female  31.920         0     no   2205.98080
# 1335   18  female  36.850         0     no   1629.83350
# 1336   21  female  25.800         0     no   2007.94500
# 1337   61  female  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %%
#transform categorical value to numerical value
dataset = pd.get_dummies(dataset, drop_first =True)
dataset = dataset.astype(int)
dataset
# Out:
#       age  bmi  children  charges  sex_male  smoker_yes
# 0      19   27         0    16884         0           1
# 1      18   33         1     1725         1           0
# 2      28   33         3     4449         1           0
# 3      33   22         0    21984         1           0
# 4      32   28         0     3866         1           0
# ...   ...  ...       ...      ...       ...         ...
# 1333   50   30         3    10600         1           0
# 1334   18   31         0     2205         0           0
# 1335   18   36         0     1629         0           0
# 1336   21   25         0     2007         0           0
# 1337   61   29         0    29141         0           1
#
# [1338 rows x 6 columns]

# %%
independent = dataset[['age', 'bmi', 'children','sex_male', 'smoker_yes']]
dependent = dataset[['charges']]

# %%
from sklearn.ensemble import AdaBoostRegressor #importing adaboost
from sklearn.model_selection import GridSearchCV # importing gridsearch to make the crossvalidation 
parameters = {'loss':['linear', 'square', 'exponential'],
              'n_estimators':[10,50,100,1000,2000],
              'random_state':[0]}

grid = GridSearchCV(AdaBoostRegressor(),parameters, refit = True, verbose =3, n_jobs=-1) #refit true is for finding the best model,
                                                                           #false will give last model
grid.fit(independent,dependent) # can able to call directly without training and testing
# Out:
# Fitting 5 folds for each of 15 candidates, totalling 75 fits
# C:\Anaconda3\Lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# GridSearchCV(estimator=AdaBoostRegressor(), n_jobs=-1,
#              param_grid={'loss': ['linear', 'square', 'exponential'],
#                          'n_estimators': [10, 50, 100, 1000, 2000],
#                          'random_state': [0]},
#              verbose=3)

# %%
print(grid.best_params_)
# Out:
# {'loss': 'linear', 'n_estimators': 10, 'random_state': 0}

# %%
regressor = grid.cv_results_ 
regressor
print('The R score value for best parameter: ',format(grid.best_params_))
# Out:
# The R score value for best parameter:  {'loss': 'linear', 'n_estimators': 10, 'random_state': 0}

# %%
table = pd.DataFrame.from_dict(regressor)
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time   param_loss  \
# 0        0.814548      0.789960         0.016585        0.001170       linear
# 1        0.617837      0.497374         0.016339        0.019776       linear
# 2        0.155191      0.034871         0.015569        0.014139       linear
# 3        0.220701      0.054266         0.015990        0.003556       linear
# 4        0.207306      0.042812         0.016455        0.021925       linear
# 5        0.178754      0.018520         0.015336        0.010651       square
# 6        0.903643      0.185899         0.059600        0.016529       square
# 7        1.636719      0.581001         0.084170        0.024224       square
# 8        8.507378      4.872479         0.540649        0.424410       square
# 9       21.611358     14.869429         1.457479        1.229273       square
# 10       0.466050      0.288912         0.076845        0.033521  exponential
# 11       1.086948      0.032921         0.091883        0.034773  exponential
# 12       2.286852      0.403539         0.114230        0.011753  exponential
# 13      20.118038      0.316189         1.086238        0.570659  exponential
# 14      28.666481      5.390342         1.578637        0.238358  exponential
#
#    param_n_estimators param_random_state  \
# 0                  10                  0
# 1                  50                  0
# 2                 100                  0
# 3                1000                  0
# 4                2000                  0
# 5                  10                  0
# 6                  50                  0
# 7                 100                  0
# 8                1000                  0
# 9                2000                  0
# 10                 10                  0
# 11                 50                  0
# 12                100                  0
# 13               1000                  0
# 14               2000                  0
#
#                                                params  split0_test_score  \
# 0   {'loss': 'linear', 'n_estimators': 10, 'random...           0.807455
# 1   {'loss': 'linear', 'n_estimators': 50, 'random...           0.799801
# 2   {'loss': 'linear', 'n_estimators': 100, 'rando...           0.799801
# 3   {'loss': 'linear', 'n_estimators': 1000, 'rand...           0.799801
# 4   {'loss': 'linear', 'n_estimators': 2000, 'rand...           0.799801
# 5   {'loss': 'square', 'n_estimators': 10, 'random...           0.710044
# 6   {'loss': 'square', 'n_estimators': 50, 'random...           0.565551
# 7   {'loss': 'square', 'n_estimators': 100, 'rando...           0.540889
# 8   {'loss': 'square', 'n_estimators': 1000, 'rand...           0.487417
# 9   {'loss': 'square', 'n_estimators': 2000, 'rand...           0.481938
# 10  {'loss': 'exponential', 'n_estimators': 10, 'r...           0.804864
# 11  {'loss': 'exponential', 'n_estimators': 50, 'r...           0.624071
# 12  {'loss': 'exponential', 'n_estimators': 100, '...           0.562505
# 13  {'loss': 'exponential', 'n_estimators': 1000, ...           0.490037
# 14  {'loss': 'exponential', 'n_estimators': 2000, ...           0.489599
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.772015           0.830049           0.788747
# 1            0.772015           0.830049           0.768749
# 2            0.772015           0.830049           0.768749
# 3            0.772015           0.830049           0.768749
# 4            0.772015           0.830049           0.768749
# 5            0.649105           0.630632           0.643657
# 6            0.388542           0.481348           0.508776
# 7            0.388542           0.469547           0.500670
# 8            0.388542           0.431248           0.536599
# 9            0.388542           0.431248           0.533700
# 10           0.756367           0.792046           0.769837
# 11           0.521036           0.588144           0.574184
# 12           0.408587           0.481703           0.494275
# 13           0.314663           0.387007           0.413406
# 14           0.309286           0.392079           0.408961
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0            0.832317         0.806116        0.023348                1
# 1            0.832317         0.800586        0.027223                2
# 2            0.832317         0.800586        0.027223                2
# 3            0.832317         0.800586        0.027223                2
# 4            0.832317         0.800586        0.027223                2
# 5            0.693735         0.665435        0.030800                7
# 6            0.456373         0.480118        0.058432               10
# 7            0.414107         0.462751        0.055611               11
# 8            0.356482         0.440058        0.065237               12
# 9            0.352792         0.437644        0.064561               13
# 10           0.814681         0.787559        0.021644                6
# 11           0.589653         0.579418        0.033498                8
# 12           0.503788         0.490172        0.049320                9
# 13           0.416688         0.404360        0.056429               14
# 14           0.415491         0.403083        0.057607               15

# %%
age = float(input("Age: "))
bmi = float(input("BMI: "))
children = int(input("No of Children: "))
sex_male= int(input("Sex Male :0 , Female: 1: "))
smoker_yes= int(input("Smoker: 0, Non-smoker:1: "))
# Out:
# Age: 45
# BMI: 34.5
# No of Children: 3
# Sex Male :0 , Female: 1: 0
# Smoker: 0, Non-smoker:1: 1

# %%
Final_prediction =grid.predict([[age,bmi,children,sex_male,smoker_yes]])
print("Final_prediction of AdaBoost: {}".format(Final_prediction))
# Out:
# Final_prediction of AdaBoost: [46576.6122449]
# C:\Anaconda3\Lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but AdaBoostRegressor was fitted with feature names
#   warnings.warn(

# %%
# Saving the model
import pickle
filename= "AdaboostGrid_insurance.sav"

# %%
pickle.dump(grid,open(filename,'wb'))
load_model=pickle.load(open("AdaboostGrid_insurance.sav",'rb'))

# %%
result=load_model.predict([[29,23,1,0,1]])
result
# Out:
# C:\Anaconda3\Lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but AdaBoostRegressor was fitted with feature names
#   warnings.warn(
# array([19935.52631579])
